# %%
import pandas as pd
import numpy as np
import config
import json
import requests

import fiona
import geopandas as gpd

import warnings
warnings.filterwarnings("ignore")

# %%
from uszipcode import SearchEngine

# %% [markdown]
# ### We only want to keep target states
# FL    12<br>
# VA    51<br>
# NC    37<br>
# GA    13<br>
# WV    54<br>
# MD    24<br>
# SC    45<br>
# DC    11<br>

# %% [markdown]
# ## (1) School Districts geoJSON to grab list of GEOIDS & School Districts

# %%
#upload geojson school boundaries file
with open('../nicole/clean_data/school_districts_simplified.json') as f2:
    schools_geodata = json.load(f2)
#schools_geodata['features']

# %%
#make a df of GEOIDs and school districts
dict_schools = {}
for each in schools_geodata['features']:
    dict_schools[each['properties']['GEOID']] = each['properties']['NAME']

geoid_schools = pd.DataFrame.from_dict(dict_schools, orient='index').reset_index()
geoid_schools.columns = ['GEOID','school_district']

# %% [markdown]
# ## (2) GreatSchools.org Scrape Demographics

# %%
#upload school district info from greatschools.org scrape
df = pd.read_json('../jack/General/data/great_schools.json') 
df['pctLowIncome'] = df['pctLowIncome'].str.rstrip('%').replace('?', -1).astype(float)
df['pctLowIncome'] = df['pctLowIncome'].replace(-1, np.nan)
#historical = historical[df["LOT SIZE"].notna()]

# %%
#grab just the relevant columns we want from greatschools df
greatschools_agg = df.groupby('districtName').agg(avg_rating =('overallRating','mean'), total_enrollment= ('enrollment', 'sum'),
                                                  num_schools=('enrollment','nunique'), avg_pct_low_income=('pctLowIncome','mean'),
                                                  state = ('state', lambda x: x.value_counts().index[0])).round(1).reset_index()
greatschools_agg = greatschools_agg.rename(columns={'districtName':'school_district'})
greatschools_agg = greatschools_agg[greatschools_agg['total_enrollment'] > 15]

# df1 = (df.groupby(['road','dirn'], as_index=False)
#          .agg({'length':'sum','lane':lambda x: x.value_counts().index[0]}))

#df2['school_district'] = df2['school_district'].str.replace(r'\School\b','School District')
#df2['school_district'] = df2['school_district'].str.replace(r'\Schools\b','School District')
#df3 = df2[df2['school_district'].str.contains(r'\School\b')]
#df2.loc[df2['school_district'] == 'Lee County Schools']

greatschools_agg
# Out:
#                              school_district  avg_rating  total_enrollment  \
# 1                             A.C.E. Academy         5.0               409
# 2                               Abbeville 60         6.7              3012
# 3                 Accomack Co Public Schools         4.6              5115
# 4        Achievement Preparatory Academy PCS         3.0               825
# 5                       Ahfachkee Day School         NaN               177
# ...                                      ...         ...               ...
# 1077                                 York 04         7.9             16081
# 1078                  York Co Public Schools         7.0             12750
# 1079                     Youngsville Academy         5.0               332
# 1080                          Youthbuild PCS         NaN               302
# 1081  Z.E.C.A. School of Arts and Technology         4.0               162
#
#       num_schools  avg_pct_low_income state
# 1               1                56.0    NC
# 2               9                68.5    SC
# 3              12                64.5    VA
# 4               2                76.0    DC
# 5               1               100.0    FL
# ...           ...                 ...   ...
# 1077           17                16.0    SC
# 1078           18                23.8    VA
# 1079            1                 3.0    NC
# 1080            2                70.0    DC
# 1081            1                98.0    NC
#
# [956 rows x 6 columns]

# %%
greatschools_agg = greatschools_agg.sort_values('total_enrollment', ascending = False).head(750)

# %% [markdown]
# #### Save to CSVs

# %%
#from geoJSON to grab geoIDS
geoid_schools.to_csv('../nicole/clean_data/geoIDs_district_names.csv')

#from greatschools.org
greatschools_agg.to_csv('../nicole/clean_data/greatschools_scrape.csv')

#next step is to merge these two....

# %% [markdown]
# ## (3) Matching GreatSchools.org districts with GeoIDs

# %% [markdown]
# - Finding School Districts by 'first word'

# %%
#import csv of first words of every school district (did this in excel)
first_words = pd.read_csv('../nicole/clean_data/first_word_geoID.csv')
list_first_words= first_words['first_word'].tolist()

# list of sentences form greatschools
list_sentences = greatschools_agg['school_district'].tolist()

#list_first_words

# %%
#matching first words with sentences that contain said word
dict_sentence_word = {}
for word in list_first_words:
    for i, sentence in enumerate(list_sentences):
        if word in sentence:
            dict_sentence_word[sentence] = word     
dict_sentence_word
# Out:
# {'District of Columbia Public Schools': 'Columbia',
#  'District of Columbia International School': 'Columbia',
#  'Alachua': 'Alachua',
#  'Baker': 'Baker',
#  'Bay': 'Bay',
#  'Bradford': 'Bradford',
#  'Bradford Preparatory School': 'Bradford',
#  'Brevard': 'Brevard',
#  'Broward': 'Broward',
#  'Calhoun City': 'Calhoun',
#  'Calhoun': 'Calhoun',
#  'Calhoun 01': 'Calhoun',
#  'Calhoun County Schools': 'Calhoun',
#  'Charlotte-Mecklenburg Schools': 'Mecklenburg',
#  'Charlotte': 'Charlotte',
#  'Charlottesville Cty Public Schools': 'Charlottesville',
#  'Charlotte Co Public Schools': 'Charlotte',
#  'KIPP: Charlotte': 'Charlotte',
#  'Charlotte Lab School': 'Charlotte',
#  'Citrus': 'Citrus',
#  'Clayton County': 'Clay',
#  'Clay': 'Clay',
#  'Clay County Schools': 'Clay',
#  'Collier': 'Collier',
#  'Columbia County': 'Columbia',
#  'Columbia': 'Columbia',
#  'Miami-Dade': 'Dade',
#  'Dade County': 'Dade',
#  'Dixie': 'Dixie',
#  'Duval': 'Duval',
#  'Escambia': 'Escambia',
#  'Flagler': 'Flagler',
#  'Franklin County Schools': 'Franklin',
#  'Franklin Co Public Schools': 'Franklin',
#  'Franklin County': 'Franklin',
#  'Franklin Academy': 'Franklin',
#  'Franklin': 'Franklin',
#  'Franklin City Public Schools': 'Franklin',
#  'Gadsden': 'Gadsden',
#  'Gilchrist': 'Gilchrist',
#  'Glades': 'Glades',
#  'Gulf': 'Gulf',
#  'Hamilton': 'Hamilton',
#  'Hardee': 'Hardee',
#  'Hendry': 'Hendry',
#  'Hernando': 'Hernando',
#  'Highlands': 'Highland',
#  'Hillsborough': 'Hillsborough',
#  'Holmes': 'Holmes',
#  'Indian River': 'Indian River',
#  'Jackson County': 'Jackson',
#  'Jackson': 'Jackson',
#  'Jackson County Schools': 'Jackson',
#  'Jackson County Public Schools': 'Jackson',
#  'Jefferson County Schools': 'Jefferson',
#  'Jefferson City': 'Jefferson',
#  'Jefferson County': 'Jefferson',
#  'Thomas Jefferson Classical Academy': 'Jefferson',
#  'Jefferson': 'Jefferson',
#  'Lafayette': 'Lafayette',
#  'Lake': 'Lake',
#  'Lake Norman Charter': 'Lake',
#  'Pine Lake Preparatory': 'Lake',
#  'Falls Lake Academy': 'Falls',
#  'Lee': 'Lee',
#  'Lee County Schools': 'Lee',
#  'Lee County': 'Lee',
#  'Lee Co Public Schools': 'Lee',
#  'Lee 01': 'Lee',
#  'Leon': 'Leon',
#  'Levy': 'Levy',
#  'Liberty County': 'Liberty',
#  'Liberty': 'Liberty',
#  'Madison County': 'Madison',
#  'Madison': 'Madison',
#  'Madison County Schools': 'Madison',
#  'Madison Co Public Schools': 'Madison',
#  'Manatee': 'Manatee',
#  'Marion': 'Marion',
#  'Marion County Schools': 'Marion',
#  'Marion 10': 'Marion',
#  'Marion County': 'Marion',
#  'Martin': 'Martin',
#  'Martin County Schools': 'Martin County Schools',
#  'Martinsville City Public Schools': 'Martinsville',
#  'Monroe': 'Monroe',
#  'Monroe County': 'Monroe',
#  'Monroe County Schools': 'Monroe',
#  'Nassau': 'Nassau',
#  'Okaloosa': 'Okaloosa',
#  'Okeechobee': 'Okeechobee',
#  'Orange': 'Orange',
#  'Orange County Schools': 'Orange',
#  'Orangeburg 05': 'Orange',
#  'Orange Co Public Schools': 'Orange',
#  'Orangeburg 04': 'Orange',
#  'Orangeburg 03': 'Orange',
#  'Osceola': 'Osceola',
#  'Palm Beach': 'Palm',
#  'Pasco': 'Pasco',
#  'Pinellas': 'Pinellas',
#  'Polk': 'Polk',
#  'Polk County': 'Polk',
#  'Polk County Schools': 'Polk',
#  'Putnam': 'Putnam',
#  'Putnam County Schools': 'Putnam',
#  'Putnam County': 'Putnam',
#  'Santa Rosa': 'Santa',
#  'Sarasota': 'Sarasota',
#  'Seminole': 'Seminole',
#  'Seminole County': 'Seminole',
#  'St. Johns': 'St. Johns',
#  'St. Lucie': 'St. Lucie',
#  'Sumter 01': 'Sumter',
#  'Sumter': 'Sumter',
#  'Sumter County': 'Sumter',
#  'Suwannee': 'Suwannee',
#  'Taylor': 'Taylor',
#  'Taylor County Schools': 'Taylor',
#  'Taylor County': 'Taylor',
#  'Union County Public Schools': 'Union',
#  'Union 01': 'Union',
#  'Union County': 'Union',
#  'Union': 'Union',
#  'Union Academy Charter School': 'Union',
#  'Union Preparatory Academy at Indian Trai': 'Union',
#  'Volusia': 'Volusia',
#  'Wakulla': 'Wakulla',
#  'Walton County': 'Walton',
#  'Walton': 'Walton',
#  'Washington Co Public Schools': 'Washington',
#  'Washington': 'Washington',
#  'Washington County': 'Washington',
#  'Washington County Schools': 'Washington',
#  'Washington Latin Pcs': 'Washington',
#  'Troup County': 'Troup',
#  'Appling County': 'Appling',
#  'Atkinson County': 'Atkinson',
#  'Atlanta Public Schools': 'Atlanta',
#  'Commission Charter Schools- Atlanta Heights Charter School': 'Atlanta',
#  'Bacon County': 'Bacon',
#  'Baldwin County': 'Baldwin',
#  'Banks County': 'Banks',
#  'Barrow County': 'Barrow',
#  'Bartow County': 'Bartow',
#  'Ben Hill County': 'Ben Hill ',
#  'Berrien County': 'Berrien',
#  'Bibb County': 'Bibb',
#  'Bleckley County': 'Bleckley',
#  'Brantley County': 'Brantley',
#  'Bremen City': 'Bremen',
#  'Brooks County': 'Brooks',
#  'Bryan County': 'Bryan',
#  'Buford City': 'Buford',
#  'Bulloch County': 'Bulloch',
#  'Burke County Schools': 'Burke',
#  'Burke County': 'Burke',
#  'Butts County': 'Butts',
#  'Camden County': 'Camden',
#  'Camden County Schools': 'Camden',
#  'Candler County': 'Candler',
#  'Carroll County Public Schools': 'Carroll',
#  'Carroll County': 'Carroll',
#  'Carrollton City': 'Carroll',
#  'Carroll Co Public Schools': 'Carroll',
#  'Cartersville City': 'Cartersville',
#  'Catoosa County': 'Catoosa',
#  'Charlton County': 'Charlton',
#  'Savannah-Chatham County': 'Chatham',
#  'Chatham County Schools': 'Chatham',
#  'Chattahoochee County': 'Chattahoochee',
#  'Chattooga County': 'Chattooga',
#  'Cherokee County': 'Cherokee',
#  'Cherokee 01': 'Cherokee',
#  'Cherokee County Schools': 'Cherokee',
#  'State Charter Schools- Cherokee Charter Academy': 'Cherokee',
#  'Chickamauga City': 'Chickamauga',
#  'Clarke County': 'Clarke',
#  'Clarke Co Public Schools': 'Clarke',
#  'Clinch County': 'Clinch',
#  'Cobb County': 'Cobb',
#  'Coffee County': 'Coffee',
#  'Colquitt County': 'Colquitt',
#  'Commerce City': 'Commerce',
#  'Cook County': 'Cook',
#  'Coweta County': 'Coweta',
#  'Commission Charter Schools- Coweta Charter Academy': 'Coweta',
#  'Crawford County': 'Crawford',
#  'Crisp County': 'Crisp',
#  'Dalton Public Schools': 'Dalton',
#  'Dawson County': 'Dawson',
#  'City Schools of Decatur': 'Decatur',
#  'Decatur County': 'Decatur',
#  'DeKalb County': 'DeKalb',
#  'Dodge County': 'Dodge',
#  'Dooly County': 'Dooly',
#  'Dougherty County': 'Dougherty',
#  'Douglas County': 'Douglas',
#  'Dublin City': 'Dublin',
#  'Laurens County': 'Laurens',
#  'Laurens 55': 'Laurens 55',
#  'Laurens 56': 'Laurens 56',
#  'Early County': 'Early',
#  'Echols County': 'Echols',
#  'Effingham County': 'Effingham',
#  'Elbert County': 'Elbert',
#  'Emanuel County': 'Emanuel',
#  'Evans County': 'Evans',
#  'Fannin County': 'Fannin',
#  'Fayette County': 'Fayette',
#  'Fayette County Schools': 'Fayette',
#  'Floyd County': 'Floyd',
#  'Floyd Co Public Schools': 'Floyd',
#  'Winston Salem   Forsyth County Schools': 'Salem',
#  'Forsyth County': 'Forsyth',
#  'Forsyth Academy': 'Forsyth',
#  'Fulton County': 'Fulton',
#  'Gainesville City': 'Gainesville',
#  'Gilmer County': 'Gilmer',
#  'Gilmer County Schools': 'Gilmer',
#  'Glynn County': 'Glynn',
#  'Gordon County': 'Gordon',
#  'Grady County': 'Grady',
#  'Greene Co Public Schools': 'Greene',
#  'Greene County Schools': 'Greene',
#  'Greene County': 'Greene',
#  'Griffin-Spalding County': 'Spalding',
#  'Gwinnett County': 'Gwinnett',
#  'Habersham County': 'Habersham',
#  'Hall County': 'Hall',
#  'Hancock County Schools': 'Hancock',
#  'Hancock County': 'Hancock',
#  'Haralson County': 'Haralson',
#  'Harrison County Schools': 'Harrison',
#  'Harrisonburg City Public Schools': 'Harrison',
#  'Harris County': 'Harris',
#  'Hart County': 'Hart',
#  'Heard County': 'Heard',
#  'Henry County': 'Henry',
#  'Henry Co Public Schools': 'Henry',
#  'Houston County': 'Houston',
#  'Irwin County': 'Irwin',
#  'Jasper 01': 'Jasper',
#  'Jasper County': 'Jasper',
#  'Jeff Davis County': 'Jeff',
#  'Jenkins County': 'Jenkins',
#  'Johnson County': 'Johnson',
#  'Jones County': 'Jones',
#  'Jones County Schools': 'Jones',
#  'Lamar County': 'Lamar',
#  'Lanier County': 'Lanier',
#  'Lincoln County Schools': 'Lincoln',
#  'Lincoln Charter School': 'Lincoln',
#  'Lincoln County': 'Lincoln',
#  'Long County': 'Long',
#  'Lowndes County': 'Lowndes',
#  'Lumpkin County': 'Lumpkin',
#  'Macon County Schools': 'Macon',
#  'Macon County': 'Macon',
#  'Marietta City': 'Marietta',
#  'McDuffie County': 'McDuffie',
#  'McIntosh County': 'McIntosh',
#  'Meriwether County': 'Meriwether',
#  'Miller County': 'Miller',
#  'Mitchell County': 'Mitchell',
#  'Mitchell County Schools': 'Mitchell',
#  'Montgomery County Public Schools': 'Montgomery',
#  'Montgomery Co Public Schools': 'Montgomery',
#  'Montgomery County Schools': 'Montgomery',
#  'Montgomery County': 'Montgomery',
#  'Morgan County': 'Morgan',
#  'Morgan County Schools': 'Morgan',
#  'Murray County': 'Murray',
#  'Muscogee County': 'Muscogee',
#  'Newton County': 'New',
#  'Newton Conover City Schools': 'New',
#  'Oconee 01': 'Oconee',
#  'Oconee County': 'Oconee',
#  'Oglethorpe County': 'Oglethorpe',
#  'Paulding County': 'Paulding',
#  'Peach County': 'Peach',
#  'Pelham City': 'Pelham',
#  'Pickens 01': 'Pickens',
#  'Pickens County': 'Pickens',
#  'Pierce County': 'Pierce',
#  'Pike County': 'Pike',
#  'Pulaski Co Public Schools': 'Pulaski',
#  'Pulaski County': 'Pulaski',
#  'Rabun County': 'Rabun',
#  'Randolph County School System': 'Randolph',
#  'Randolph County Schools': 'Randolph',
#  'Randolph County': 'Randolph',
#  'Richmond County': 'Richmond County',
#  'Richmond City Public Schools': 'Richmond City ',
#  'Richmond County Schools': 'Richmond County',
#  'Richmond Co Public Schools': 'Richmond',
#  'Rockdale County': 'Rockdale',
#  'Rome City': 'Rome',
#  'Schley County': 'Schley',
#  'Screven County': 'Screven',
#  'Social Circle City': 'Social',
#  'Stephens County': 'Stephens',
#  'Talbot County Public Schools': 'Talbot County',
#  'Tattnall County': 'Tattnall',
#  'Telfair County': 'Telfair',
#  'Terrell County': 'Terrell',
#  'Thomas County': 'Thomas',
#  'Thomaston-Upson County': 'Upson',
#  'Thomasville City': 'Thomasville',
#  'Thomasville City Schools': 'Thomasville',
#  'Tift County': 'Tift',
#  'Toombs County': 'Toombs',
#  'Towns County': 'Towns',
#  'Treutlen County': 'Treutlen',
#  'Trion City': 'Trion',
#  'Turner County': 'Turner',
#  'Twiggs County': 'Twiggs',
#  'Valdosta City': 'Valdosta',
#  'Vidalia City': 'Vidalia',
#  'Walker County': 'Walker',
#  'Ware County': 'Ware',
#  'Warren Co Public Schools': 'Warren',
#  'Warren County Schools': 'Warren',
#  'Warren County': 'Warren',
#  'Wayne County Public Schools': 'Wayne',
#  'Wayne County Schools': 'Wayne',
#  'Wayne County': 'Wayne',
#  'Waynesboro City Public Schools': 'Wayne',
#  'Wayne Preparatory': 'Wayne',
#  'Webster County Schools': 'Webster',
#  'Wheeler County': 'Wheeler',
#  'White County': 'White',
#  'Whiteville City Schools': 'Whiteville',
#  'Whitfield County': 'Whitfield',
#  'Wilcox County': 'Wilcox',
#  'Wilkes County Schools': 'Wilkes',
#  'Wilkes County': 'Wilkes',
#  'Wilkinson County': 'Wilkinson',
#  'Worth County': 'Worth',
#  'Allegany County Public Schools': 'Allegany',
#  'Anne Arundel County Public Schools': 'Anne',
#  "Queen Anne's County Public Schools": 'Queen',
#  'Baltimore County Public Schools': 'Baltimore',
#  'Baltimore City Public Schools': 'Baltimore',
#  'Calvert County Public Schools': 'Calvert',
#  'Caroline County Public Schools': 'Caroline',
#  'Caroline Co Public Schools': 'Caroline',
#  'Cecil County Public Schools': 'Cecil',
#  'Charleston 01': 'Charles',
#  'Charles County Public Schools': 'Charles',
#  'Charles City Co Public Schools': 'Charles',
#  'Dorchester 02': 'Dorchester',
#  'Dorchester County Public Schools': 'Dorchester',
#  'Dorchester 04': 'Dorchester',
#  'Frederick County Public Schools': 'Frederick',
#  'Frederick Co Public Schools': 'Frederick',
#  'Fredericksburg City Public Schools': 'Fredericksburg',
#  'Garrett County Public Schools': 'Garrett',
#  'Harford County Public Schools': 'Harford',
#  'Howard County Public Schools': 'Howard',
#  'Sallie B Howard School': 'Howard',
#  'New Kent Co Public Schools': 'New',
#  'Kent County Public Schools': 'Kent',
#  "Prince George's County Public Schools": 'Prince',
#  'Prince William Co Public Schools': 'Prince William',
#  'Prince George Co Public Schools': 'Prince George ',
#  'Prince Edward Co Public Schools': 'Prince Edward ',
#  "Queen's Grant Community School": 'Grant',
#  'King and Queen Co Public Schools': 'King and Queen',
#  'Somerset County Public Schools': 'Somerset',
#  'Wicomico County Public Schools': 'Wicomico',
#  'Worcester County Public Schools': 'Worcester',
#  'Cumberland County Schools': 'Cumberland',
#  'Cumberland Co Public Schools': 'Cumberland',
#  'Pitt County Schools': 'Pitt',
#  'Pittsylvania Co Public Schools': 'Pittsylvania',
#  'Campbell Co Public Schools': 'Campbell',
#  'Alamance-Burlington Schools': 'Alamance-Burlington',
#  'Alexander County Schools': 'Alexander',
#  'Alleghany Co Public Schools': 'Alleghany',
#  'Alleghany County Schools': 'Alleghany',
#  'Anson County Schools': 'Anson',
#  'Asheboro City Schools': 'Asheboro',
#  'Asheville City Schools': 'Asheville',
#  'Ashe County Schools': 'Ashe',
#  'Avery County Schools': 'Avery',
#  'Beaufort 01': 'Beaufort',
#  'Beaufort County Schools': 'Beaufort',
#  'Bertie County Schools': 'Bertie',
#  'Bladen County Schools': 'Bladen',
#  'Brunswick County Schools': 'Brunswick',
#  'Brunswick Co Public Schools': 'Brunswick',
#  'Buncombe County Schools': 'Buncombe',
#  'Cabarrus County Schools': 'Cabarrus',
#  'Cabarrus Charter Academy': 'Cabarrus',
#  'Caldwell County Schools': 'Caldwell',
#  'Carteret County Public Schools': 'Carteret',
#  'Caswell County Schools': 'Caswell',
#  'Catawba County Schools': 'Catawba',
#  'Chapel Hill-Carrboro City Schools': 'Chapel Hill-Carrboro',
#  'Edenton-Chowan Schools': 'Edenton-Chowan',
#  'Cleveland County Schools': 'Cleveland',
#  'Clinton City Schools': 'Clinton',
#  'Columbus County Schools': 'Columbus',
#  'Columbus Charter School': 'Columbus',
#  'Currituck County Schools': 'Currituck',
#  'Dare County Schools': 'Dare',
#  'Davidson County Schools': 'Davidson',
#  'Community School of Davidson': 'Davidson',
#  'Davie County Schools': 'Davie',
#  'Duplin County Schools': 'Duplin',
#  'Durham Public Schools': 'Durham Public',
#  'Edgecombe County Public Schools': 'Edgecombe',
#  'Elkin City Schools': 'Elkin',
#  'Gaston County Schools': 'Gaston',
#  'Gaston College Preparatory': 'Gaston',
#  'Gates County Schools': 'Gates',
#  'Graham County Schools': 'Graham',
#  'Granville County Schools': 'Granville',
#  'Guilford County Schools': 'Guilford',
#  'Halifax Co Public Schools': 'Halifax',
#  'Halifax County Schools': 'Halifax',
#  'Harnett County Schools': 'Harnett',
#  'Haywood County Schools': 'Haywood',
#  'Henderson County Schools': 'Henderson',
#  'Henderson Collegiate': 'Henderson',
#  'Hertford County Schools': 'Hertford',
#  'Hickory City Schools': 'Hickory',
#  'Hoke County Schools': 'Hoke',
#  'Hyde County Schools': 'Hyde',
#  'Iredell-Statesville Schools': 'Iredell-Statesville',
#  'Johnston County Public Schools': 'Johnston',
#  'Johnston Charter Academy': 'Johnston',
#  'Kannapolis City Schools': 'Kannapolis',
#  'Lenoir County Public Schools': 'Lenoir',
#  'Lexington 01': 'Lexington 01',
#  'Lexington 05': 'Lexington 05',
#  'Lexington 02': 'Lexington 02',
#  'Lexington 04': 'Lexington 04',
#  'Lexington City Schools': 'Lexington',
#  'Lexington 03': 'Lexington 03',
#  'McDowell County Schools': 'McDowell',
#  'Moore County Schools': 'Moore',
#  'Mooresville Graded School District': 'Mooresville',
#  'Nash-Rocky Mount Schools': 'Nash-Rocky',
#  'State Charter Schools- Mountain Education Center School': 'Mount',
#  'Mount Airy City Schools': 'Mount',
#  'Mountain Island Charter': 'Mount',
#  'Rocky Mount Preparatory': 'Mount',
#  'Craven County Schools': 'Craven',
#  'Newport News City Public Schools': 'Newport',
#  'New Hanover County Schools': 'New',
#  'Newberry 01': 'New',
#  'Northampton Co Public Schools': 'Northampton',
#  'Northampton County Schools': 'Northampton',
#  'Onslow County Schools': 'Onslow',
#  'Pamlico County Schools': 'Pamlico',
#  'Elizabeth City-Pasquotank Public Schools': 'Pasquotank',
#  'Pender County Schools': 'Pender',
#  'Perquimans County Schools': 'Perquimans',
#  'Person County Schools': 'Person',
#  'Roanoke Co Public Schools': 'Roanoke',
#  'Roanoke City Public Schools': 'Roanoke City ',
#  'Roanoke Rapids City Schools': 'Roanoke',
#  'Public Schools of Robeson County': 'Robeson',
#  'Rockingham County Schools': 'Rockingham',
#  'Rockingham Co Public Schools': 'Rockingham',
#  'Rowan-Salisbury Schools': 'Rowan-Salisbury',
#  'Rutherford County Schools': 'Rutherford',
#  'Sampson County Schools': 'Sampson',
#  'Scotland County Schools': 'Scotland',
#  'Stanly County Schools': 'Stanly',
#  'Stokes County Schools': 'Stokes',
#  'Surry County Schools': 'Surry',
#  'Surry Co Public Schools': 'Surry',
#  'Swain County Schools': 'Swain',
#  'Transylvania County Schools': 'Transylvania',
#  'Tyrrell County Schools': 'Tyrrell',
#  'Vance County Schools': 'Vance',
#  'Vance Charter School': 'Vance',
#  'Wake County Schools': 'Wake',
#  'East Wake Academy': 'Wake',
#  'Wake Forest Charter Academy': 'Wake',
#  'Southern Wake Academy': 'Wake',
#  'Watauga County Schools': 'Watauga',
#  'Weldon City Schools': 'Weldon',
#  'Wilson County Schools': 'Wilson',
#  'Wilson Preparatory Academy': 'Wilson',
#  'Yadkin County Schools': 'Yadkin',
#  'Yancey County Schools': 'Yancey',
#  'Abbeville 60': 'Abbeville',
#  'Aiken 01': 'Aiken',
#  'Allendale 01': 'Allendale',
#  'Anderson 01': 'Anderson 01',
#  'Anderson 02': 'Anderson 02',
#  'Anderson 03': 'Anderson 03',
#  'Anderson 04': 'Anderson 04',
#  'Anderson 05': 'Anderson 05',
#  'Bamberg 01': 'Bamberg 01',
#  'Bamberg 02': 'Bamberg 02',
#  'Barnwell 19': 'Barnwell 19',
#  'Barnwell 29': 'Barnwell 29',
#  'Barnwell 45': 'Barnwell 45',
#  'Berkeley 01': 'Berkeley',
#  'Berkeley County Schools': 'Berkeley',
#  'Chesterfield Co Public Schools': 'Chesterfield',
#  'Chesterfield 01': 'Chesterfield',
#  'Chester 01': 'Chester',
#  'Clarendon 01': 'Clarendon 01',
#  'Clarendon 02': 'Clarendon 02',
#  'Clarendon 03': 'Clarendon 03',
#  'Colleton 01': 'Colleton',
#  'Darlington 01': 'Darlington',
#  'Dillon 04': 'Dillon 04',
#  'Dillon 03': 'Dillon 03',
#  'Edgefield 01': 'Edgefield',
#  'Fairfield 01': 'Fairfield',
#  'Florence 01': 'Florence 01',
#  'Florence 02': 'Florence 02',
#  'Florence 03': 'Florence 03',
#  'Florence 04': 'Florence 04',
#  'Florence 05': 'Florence 05',
#  'Georgetown 01': 'Georgetown',
#  'Greenville 01': 'Greenville',
#  'Greenwood 50': 'Greenwood 50',
#  'Greenwood 51': 'Greenwood 51',
#  'Greenwood 52': 'Greenwood 52',
#  'Hampton 01': 'Hampton',
#  'Hampton 02': 'Hampton',
#  'Horry 01': 'Horry',
#  'Kershaw 01': 'Kershaw',
#  'Lancaster 01': 'Lancaster',
#  'Lancaster Co Public Schools': 'Lancaster',
#  'Marlboro 01': 'Marlboro',
#  'McCormick 01': 'McCormick',
#  'Richland 02': 'Richland',
#  'Richland 01': 'Richland',
#  'Saluda 01': 'Saluda',
#  'Spartanburg 01': 'Spartanburg 01',
#  'Spartanburg 02': 'Spartanburg 02',
#  'Spartanburg 03': 'Spartanburg 03',
#  'Spartanburg 04': 'Spartanburg 04',
#  'Spartanburg 05': 'Spartanburg 05',
#  'Spartanburg 06': 'Spartanburg 06',
#  'Spartanburg 07': 'Spartanburg 07',
#  'Williamsburg-James City Public Schools': 'Williamsburg',
#  'Williamsburg 01': 'Williamsburg',
#  'York 01': 'York',
#  'York 02': 'York',
#  'York 03': 'York',
#  'York 04': 'York',
#  'Accomack Co Public Schools': 'Accomack',
#  'Albemarle Co Public Schools': 'Albemarle',
#  'Alexandria City Public Schools': 'Alexandria',
#  'Amelia Co Public Schools': 'Amelia',
#  'Amherst Co Public Schools': 'Amherst',
#  'Appomattox Co Public Schools': 'Appomattox',
#  'Arlington Co Public Schools': 'Arlington',
#  'Augusta Co Public Schools': 'Augusta',
#  'Bedford Co Public Schools': 'Bedford',
#  'Bland Co Public Schools': 'Bland',
#  'Botetourt Co Public Schools': 'Botetourt',
#  'Bristol City Public Schools': 'Bristol',
#  'Buchanan Co Public Schools': 'Buchanan',
#  'Buckingham Co Public Schools': 'Buckingham',
#  'Buena Vista City Public Schools': 'Buena',
#  'Chesapeake City Public Schools': 'Chesapeake',
#  'Colonial Heights City Public Schools': 'Colonial',
#  'Colonial Beach Public Schools': 'Colonial',
#  'Covington City Public Schools': 'Covington City ',
#  'Culpeper Co Public Schools': 'Culpeper',
#  'Danville City Public Schools': 'Danville City ',
#  'Dickenson Co Public Schools': 'Dickenson',
#  'Dinwiddie Co Public Schools': 'Dinwiddie',
#  'Essex Co Public Schools': 'Essex',
#  'Falls Church City Public Schools': 'Falls',
#  'Fauquier Co Public Schools': 'Fauquier',
#  'Fluvanna Co Public Schools': 'Fluvanna',
#  'Galax City Public Schools': 'Galax',
#  'Giles Co Public Schools': 'Giles',
#  'Gloucester Co Public Schools': 'Gloucester',
#  'Goochland Co Public Schools': 'Goochland',
#  'Grayson Co Public Schools': 'Grayson',
#  'Greensville Co Public Schools': 'Greensville',
#  'Hampton City Public Schools': 'Hampton',
#  'Hanover Co Public Schools': 'Hanover',
#  'Henrico Co Public Schools': 'Henrico',
#  'Hopewell City Public Schools': 'Hopewell',
#  'Isle of Wight Co Public Schools': 'Isle of Wight ',
#  'King William Co Public Schools': 'King William ',
#  'Loudoun Co Public Schools': 'Loudoun',
#  'Louisa Co Public Schools': 'Louisa',
#  'Lunenburg Co Public Schools': 'Lunenburg',
#  'Lynchburg City Public Schools': 'Lynchburg',
#  'Manassas City Public Schools': 'Manassas',
#  'Manassas Park City Public Schools': 'Manassas',
#  'Mathews Co Public Schools': 'Mathews',
#  'Mecklenburg Co Public Schools': 'Mecklenburg',
#  'Middlesex Co Public Schools': 'Middlesex',
#  'Nelson Co Public Schools': 'Nelson',
#  'Norfolk City Public Schools': 'Norfolk',
#  'Northumberland Co Public Schools': 'Northumberland',
#  'Norton City Public Schools': 'Norton',
#  'Nottoway Co Public Schools': 'Nottoway',
#  'Page Co Public Schools': 'Page',
#  'Patrick Co Public Schools': 'Patrick',
#  'Petersburg City Public Schools': 'Petersburg',
#  'Poquoson City Public Schools': 'Poquoson',
#  'Portsmouth City Public Schools': 'Portsmouth',
#  'Powhatan Co Public Schools': 'Powhatan',
#  'Radford City Public Schools': 'Radford',
#  'Rappahannock Co Public Schools': 'Rappahannock',
#  'Rockbridge Co Public Schools': 'Rockbridge',
#  'Russell Co Public Schools': 'Russell',
#  'Salem City Public Schools': 'Salem',
#  'Scott Co Public Schools': 'Scott',
#  'Shenandoah Co Public Schools': 'Shenandoah',
#  'Smyth Co Public Schools': 'Smyth',
#  'Southampton Co Public Schools': 'Southampton',
#  'Spotsylvania Co Public Schools': 'Spotsylvania',
#  'Stafford Co Public Schools': 'Stafford',
#  'Staunton City Public Schools': 'Staunton',
#  'Suffolk City Public Schools': 'Suffolk',
#  'Sussex Co Public Schools': 'Sussex',
#  'Tazewell Co Public Schools': 'Tazewell',
#  'Westmoreland Co Public Schools': 'Westmoreland',
#  'West Point Public Schools': 'West',
#  'Winchester City Public Schools': 'Winchester',
#  'Wise Co Public Schools': 'Wise',
#  'Wythe Co Public Schools': 'Wythe',
#  'York Co Public Schools': 'York',
#  'Barbour County Board of Education': 'Barbour',
#  'Boone County  Schools': 'Boone',
#  'Braxton County Schools': 'Braxton',
#  'Brooke County Schools': 'Brooke',
#  'Cabell County Schools': 'Cabell',
#  'Doddridge County Schools': 'Doddridge',
#  'Grant County Schools': 'Grant',
#  'Greenbrier County Schools': 'Greenbrier',
#  'Hampshire County Schools': 'Hampshire',
#  'Hardy County Schools': 'Hardy',
#  'Kanawha County Schools': 'Kanawha',
#  'Lewis County Schools': 'Lewis',
#  'Logan County Schools': 'Logan',
#  'Marshall County Schools': 'Marshall',
#  'Mason County Schools': 'Mason',
#  'Mercer County Schools': 'Mercer',
#  'Mineral County Schools': 'Mineral',
#  'Mingo County Schools': 'Mingo',
#  'Monongalia County Schools': 'Monongalia',
#  'Nicholas County Schools': 'Nicholas',
#  'Ohio County Schools': 'Ohio',
#  'Pendleton County Schools': 'Pendleton',
#  'Pleasants County Schools': 'Pleasants',
#  'Pocahontas County Schools': 'Pocahontas',
#  'Preston County Schools': 'Preston',
#  'Raleigh County Schools': 'Raleigh',
#  'Ritchie County Schools': 'Ritchie',
#  'Roane County Schools': 'Roane',
#  'Summers County Schools': 'Summers',
#  'Tucker County Schools': 'Tucker',
#  'Tyler County Schools': 'Tyler',
#  'Upshur County Schools': 'Upshur',
#  'Wetzel County Schools': 'Wetzel',
#  'Wirt County Schools': 'Wirt',
#  'Wood County Schools': 'Wood',
#  'Wyoming County Schools': 'Wyoming'}

# %%
#finding the first words with multiple sentences
keys_per_value = {}
for sentence, first_word in dict_sentence_word.items():
    keys_per_value.setdefault(first_word, set()).add(sentence)
    
counts = {k: len(v) for k, v in keys_per_value.items()}
#counts

# %%
#making new list of first words that have 1:1 match with sentences
list_remove_first_words = list()
for k,v in counts.items():
    if v != 1:
        list_remove_first_words.append(k)
        
#list_final_first_words

# %%
#final dictionary mapping first words with sentences, indicating 1:1 match relationship

for key, value in dict(dict_sentence_word).items():
    if value in list_remove_first_words:
         del dict_sentence_word[key]

# %%
#dict_sentence_word

# %%
df_matched = pd.DataFrame.from_dict(dict_sentence_word, orient='index').reset_index()
df_matched.columns=['school_district','first_word']

df_matched.head()

#df_matched.merge(df_matched, on='school_district', how="left")
# Out:
#   school_district first_word
# 0         Alachua    Alachua
# 1           Baker      Baker
# 2             Bay        Bay
# 3         Brevard    Brevard
# 4         Broward    Broward

# %% [markdown]
# - #### Merging GreatSchools.org scrape and School Boundaries JSON on 'school_district' & 'GEOID'

# %%
combined = greatschools_agg.merge(df_matched, on='school_district', how="left").merge(
        first_words, on='first_word', how="left").merge(geoid_schools, on='school_district', how='left')


combined['GEOID'] = combined['GEOID_x'].fillna(combined['GEOID_y']).astype(float)
combined = combined.drop(['GEOID_x','GEOID_y'], axis = 1)
combined = combined.sort_values('GEOID').head(481).reset_index()
#combined.GEOID.value_counts()
combined
# Out:
#      index                      school_district  avg_rating  total_enrollment  \
# 0       42  District of Columbia Public Schools         5.7             48218
# 1       71                              Alachua         5.0             29834
# 2      312                                Baker         5.2              5060
# 3       97                                  Bay         4.9             23100
# 4       26                              Brevard         5.8             73331
# ..     ...                                  ...         ...               ...
# 476    607               Webster County Schools         4.2              1315
# 477    476                Wetzel County Schools         4.5              2527
# 478    657                  Wirt County Schools         3.0              1010
# 479    163                  Wood County Schools         6.3             12423
# 480    375               Wyoming County Schools         4.9              3947
#
#      num_schools  avg_pct_low_income state first_word  \
# 0            104                81.2    DC        NaN
# 1             60                52.2    FL    Alachua
# 2              7                33.6    FL      Baker
# 3             38                58.4    FL        Bay
# 4            100                49.7    FL    Brevard
# ..           ...                 ...   ...        ...
# 476            4                69.8    WV    Webster
# 477            9                53.6    WV     Wetzel
# 478            3                50.7    WV       Wirt
# 479           28                52.2    WV       Wood
# 480           13                50.2    WV    Wyoming
#
#                  school_district_id      GEOID
# 0                               NaN  1100030.0
# 1    Alachua County School District  1200030.0
# 2      Baker County School District  1200060.0
# 3        Bay County School District  1200090.0
# 4    Brevard County School District  1200150.0
# ..                              ...        ...
# 476  Webster County School District  5401530.0
# 477   Wetzel County School District  5401560.0
# 478     Wirt County School District  5401590.0
# 479     Wood County School District  5401620.0
# 480  Wyoming County School District  5401650.0
#
# [481 rows x 10 columns]

# %%
#geoid stuff
matched_geoid = pd.DataFrame(combined[combined['GEOID'].notna()].GEOID).astype(int).astype(object)

not_matched_geoid = geoid_schools.merge(matched_geoid.drop_duplicates(), on=['GEOID'], 
                                      how='left', indicator=True).query('_merge=="left_only"')

# %%
#combined['GEOID'].duplicated().sort_values(ascending = True).head(460)
#combined['GEOID'].isna()

combined_na = combined[combined['GEOID'].isna()].sort_values('total_enrollment', ascending = False).head(160)
combined_na
# Out:
# Empty DataFrame
# Columns: [index, school_district, avg_rating, total_enrollment, num_schools, avg_pct_low_income, state, first_word, school_district_id, GEOID]
# Index: []

# %% [markdown]
# #### Save CSVs

# %%
#GEOIDs that didnt match
not_matched_geoid.to_csv('../nicole/clean_data/not_matched_geoID.csv')

#school districts that didn't match
combined_na.to_csv('../nicole/clean_data/not_matched_school_district_NA.csv')

#final merge of (1) & (2)
combined['school_district_id'][295] = 'District of Columbia Public Schools'
combined['GEOID'] = combined['GEOID'].astype(int).astype(object)
combined.to_csv('../nicole/clean_data/school_districts_greatschools_demographics.csv')

# %%
#sanity check
#df2.loc[df2['school_district'] == 'Alachua']
#df.dropna()[df.dropna()['districtName'].str.contains('Alachua')]

# %% [markdown]
# ## (4) Historical & Current Redfin Data

# %%
pd.set_option('display.max_columns', 500)

# %%
historical = pd.read_csv('https://nycdsacapstone2021.blob.core.windows.net/time-series/combined_redfin_historical_12-05-21.csv')

# %%
historical = historical.drop_duplicates()
historical = historical.drop(columns=['NEXT OPEN HOUSE START TIME','NEXT OPEN HOUSE END TIME'
                                      ,'FAVORITE','SOURCE'
                                      ,'HOA/MONTH', 'MLS#'])

# %%
historical = historical[historical["YEAR BUILT"].notna()]
historical = historical[historical["BEDS"].notna()]
historical = historical[historical["SQUARE FEET"].notna()]
historical = historical[historical["ZIP OR POSTAL CODE"].notna()]
historical["STATUS"]= historical["STATUS"].apply(lambda x: "Sold" if x=="Sold" else "Active")
historical["YEAR BUILT"] = historical["YEAR BUILT"].astype("int")
historical["PRICE"] = historical["PRICE"].astype("int")
historical["SOLD DATE"] = pd.to_datetime(historical["SOLD DATE"].fillna(0))
historical["Year_Sold"] = historical["SOLD DATE"].apply(lambda x: x.year)
historical["Year_Sold"] = historical["Year_Sold"].replace(1970, 0)

# %%
historical["Log_price"] = np.log(historical["PRICE"])

# %%
historical.to_csv('../nicole/clean_data/historical_cleaned.csv')

# %% [markdown]
# # Files to use for mapping

# %%
print('school_districts_greatschools_demographics.csv')
combined
# Out:
# mapping_data.csv
#      index                      school_district  avg_rating  total_enrollment  \
# 0       42  District of Columbia Public Schools         5.7             48218
# 1       71                              Alachua         5.0             29834
# 2      312                                Baker         5.2              5060
# 3       97                                  Bay         4.9             23100
# 4       26                              Brevard         5.8             73331
# ..     ...                                  ...         ...               ...
# 476    607               Webster County Schools         4.2              1315
# 477    476                Wetzel County Schools         4.5              2527
# 478    657                  Wirt County Schools         3.0              1010
# 479    163                  Wood County Schools         6.3             12423
# 480    375               Wyoming County Schools         4.9              3947
#
#      num_schools  avg_pct_low_income state first_word  \
# 0            104                81.2    DC        NaN
# 1             60                52.2    FL    Alachua
# 2              7                33.6    FL      Baker
# 3             38                58.4    FL        Bay
# 4            100                49.7    FL    Brevard
# ..           ...                 ...   ...        ...
# 476            4                69.8    WV    Webster
# 477            9                53.6    WV     Wetzel
# 478            3                50.7    WV       Wirt
# 479           28                52.2    WV       Wood
# 480           13                50.2    WV    Wyoming
#
#                  school_district_id    GEOID
# 0                               NaN  1100030
# 1    Alachua County School District  1200030
# 2      Baker County School District  1200060
# 3        Bay County School District  1200090
# 4    Brevard County School District  1200150
# ..                              ...      ...
# 476  Webster County School District  5401530
# 477   Wetzel County School District  5401560
# 478     Wirt County School District  5401590
# 479     Wood County School District  5401620
# 480  Wyoming County School District  5401650
#
# [481 rows x 10 columns]

# %%
print('historical_cleaned.csv')
historical
# Out:
# historical_cleaned.csv
#           SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0       MLS Listing 1970-01-01  Single Family Residential
# 1       MLS Listing 1970-01-01  Single Family Residential
# 2       MLS Listing 1970-01-01  Single Family Residential
# 3       MLS Listing 1970-01-01  Single Family Residential
# 4       MLS Listing 1970-01-01  Single Family Residential
# ...             ...        ...                        ...
# 304225    PAST SALE 2019-10-31  Single Family Residential
# 304226    PAST SALE 2019-09-20  Single Family Residential
# 304227    PAST SALE 2019-01-14                  Townhouse
# 304228    PAST SALE 2020-12-21                  Townhouse
# 304229    PAST SALE 2020-02-24  Single Family Residential
#
#                      ADDRESS              CITY STATE OR PROVINCE  \
# 0                1412 Lee Ln          Hopewell                VA
# 1              812 North Ave          Hopewell                VA
# 2          102 S Colonial Dr          Hopewell                VA
# 3         3919 Robin Hood Dr          Hopewell                VA
# 4              3028 Grace St          Hopewell                VA
# ...                      ...               ...               ...
# 304225      318 N Linden Ave  Highland Springs                VA
# 304226         401 Kramer Dr  Highland Springs                VA
# 304227         302 Bernie Ct           Henrico                VA
# 304228         319 Bernie Ct           Henrico                VA
# 304229  1751 N Washington St  Highland Springs                VA
#
#        ZIP OR POSTAL CODE   PRICE  BEDS  BATHS                       LOCATION  \
# 0                   23860  169900   3.0    2.0                        Belmont
# 1                   23860  275000   4.0    3.0                    FARMINGDALE
# 2                   23860  242950   3.0    2.0            Edwin Sims Property
# 3                   23860  199000   4.0    2.0  Prince George Court Section F
# 4                   23860  229750   3.0    2.0                     Kenilworth
# ...                   ...     ...   ...    ...                            ...
# 304225              23075  180000   3.0    2.0                 Greendale Park
# 304226              23075  167000   3.0    2.0                     Meadowview
# 304227              23075   63000   3.0    1.5            Fairlawn Townhouses
# 304228              23075   73000   3.0    1.5                       Fairlawn
# 304229              23075  202000   3.0    2.0                            NaN
#
#         SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  \
# 0            1040.0   10018.0        1997             2.0          163.0
# 1            2506.0       NaN        1971             3.0          110.0
# 2            1611.0   12632.0        1960             6.0          151.0
# 3            1663.0   13503.0        1984             6.0          120.0
# 4            1484.0   14810.0        1955            10.0          155.0
# ...             ...       ...         ...             ...            ...
# 304225       2131.0   39639.0        1955           766.0           84.0
# 304226       1688.0   11325.0        1958           807.0           99.0
# 304227       1061.0    1742.0        1977          1056.0           59.0
# 304228       1061.0    1742.0        1977           349.0           69.0
# 304229       1647.0   72745.0        1978           650.0          123.0
#
#         STATUS  \
# 0       Active
# 1       Active
# 2       Active
# 3       Active
# 4       Active
# ...        ...
# 304225    Sold
# 304226    Sold
# 304227    Sold
# 304228    Sold
# 304229    Sold
#
#        URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 0       https://www.redfin.com/VA/Hopewell/1412-Lee-Ln...
# 1       https://www.redfin.com/VA/Hopewell/812-North-A...
# 2       https://www.redfin.com/VA/Hopewell/102-S-Colon...
# 3       https://www.redfin.com/VA/Hopewell/3919-Robin-...
# 4       https://www.redfin.com/VA/Hopewell/3028-Grace-...
# ...                                                   ...
# 304225  https://www.redfin.com/VA/Highland-Springs/318...
# 304226  https://www.redfin.com/VA/Highland-Springs/401...
# 304227  https://www.redfin.com/VA/Highland-Springs/302...
# 304228  https://www.redfin.com/VA/Highland-Springs/319...
# 304229  https://www.redfin.com/VA/Highland-Springs/175...
#
#        INTERESTED   LATITUDE  LONGITUDE  Year_Sold  Log_price
# 0               Y  37.273772 -77.301207          0  12.042965
# 1               Y  37.279344 -77.316350          0  12.524526
# 2               Y  37.297638 -77.319467          0  12.400611
# 3               Y  37.303146 -77.331629          0  12.201060
# 4               Y  37.298924 -77.315952          0  12.344747
# ...           ...        ...        ...        ...        ...
# 304225          Y  37.551286 -77.316266       2019  12.100712
# 304226          Y  37.553499 -77.323805       2019  12.025749
# 304227          Y  37.535703 -77.314729       2019  11.050890
# 304228          Y  37.535871 -77.313851       2020  11.198215
# 304229          Y  37.551691 -77.302668       2020  12.216023
#
# [179470 rows x 23 columns]

# %% [markdown]
# ## Upload to Azure Storage (?)

# %%
from azure.storage.blob import BlobClient
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__

import os

# IMPORTANT: Replace connection string with your storage account connection string
# Usually starts with DefaultEndpointsProtocol=https;...

CONNECTIONSTRING = os.environ.get("AZURE_STORAGE_CONNECTIONSTRING", dtype=str)
CONNECTIONSTRING

    
# Replace with blob container. This should be already created in azure storage.
MY_IMAGE_CONTAINER = "mapping"
 
# Replace with the local folder which contains the image files for upload
LOCAL_IMAGE_PATH = "../nicole/clean_data/mapping_data.csv"
 
class AzureBlobFileUploader:
    def __init__(self):
        print("Intializing AzureBlobFileUploader")

    # Initialize the connection to Azure storage account
    self.blob_service_client =  BlobServiceClient.from_connection_string(CONNECTIONSTRING)

    def upload_all_images_in_folder(self):
    # Get all files with jpg extension and exclude directories
        all_file_names = [f for f in os.listdir(LOCAL_IMAGE_PATH)
                        if os.path.isfile(os.path.join(LOCAL_IMAGE_PATH, f)) and ".jpg" in f]

    # Upload each file
    for file_name in all_file_names:
        self.upload_image(file_name)

    def upload_image(self,file_name):
    # Create blob with same name as local file name
        blob_client = self.blob_service_client.get_blob_client(container=MY_IMAGE_CONTAINER,
                                                              blob=file_name)
    # Get full path to the file
        upload_file_path = os.path.join(LOCAL_IMAGE_PATH, file_name)

    # Create blob on storage
    # Overwrite if it already exists!
    image_content_setting = ContentSettings(content_type='image/jpeg')
    print(f"uploading file - {file_name}")
    with open(upload_file_path, "rb") as data:
        blob_client.upload_blob(data,overwrite=True,content_settings=image_content_setting)


# Initialize class and upload files
azure_blob_file_uploader = AzureBlobFileUploader()
azure_blob_file_uploader.upload_all_images_in_folder()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/rq/s81db4sn0tl61l05qmsldf5r0000gn/T/ipykernel_48137/4292318182.py in <module>
#       7 # Usually starts with DefaultEndpointsProtocol=https;...
#       8
# ----> 9 CONNECTIONSTRING = os.environ.get("AZURE_STORAGE_CONNECTIONSTRING", dtype=str)
#      10 CONNECTIONSTRING
#      11
#
# TypeError: get() got an unexpected keyword argument 'dtype'
