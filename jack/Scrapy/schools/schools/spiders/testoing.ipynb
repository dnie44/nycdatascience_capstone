# %%
import pandas as pd

# %%
zips = pd.read_csv('smh_zips.txt')
zip_codes = zips['ZipCode']
zip_codes =zip_codes.tolist()

# %%
zip_codes
# Out:
# [20001,
#  20002,
#  20003,
#  20004,
#  20005,
#  20006,
#  20007,
#  20008,
#  20009,
#  20010,
#  20011,
#  20012,
#  20013,
#  20015,
#  20016,
#  20017,
#  20018,
#  20019,
#  20020,
#  20022,
#  20024,
#  20026,
#  20027,
#  20029,
#  20030,
#  20032,
#  20033,
#  20035,
#  20036,
#  20037,
#  20038,
#  20039,
#  20040,
#  20041,
#  20042,
#  20043,
#  20044,
#  20045,
#  20047,
#  20049,
#  20050,
#  20052,
#  20053,
#  20055,
#  20056,
#  20057,
#  20058,
#  20059,
#  20060,
#  20061,
#  20062,
#  20063,
#  20064,
#  20065,
#  20066,
#  20067,
#  20068,
#  20069,
#  20070,
#  20071,
#  20073,
#  20074,
#  20075,
#  20076,
#  20077,
#  20078,
#  20080,
#  20081,
#  20082,
#  20090,
#  20091,
#  20101,
#  20102,
#  20103,
#  20104,
#  20105,
#  20106,
#  20108,
#  20109,
#  20110,
#  20111,
#  20112,
#  20113,
#  20115,
#  20116,
#  20117,
#  20118,
#  20119,
#  20120,
#  20121,
#  20122,
#  20124,
#  20128,
#  20129,
#  20130,
#  20131,
#  20132,
#  20134,
#  20135,
#  20136,
# ...
